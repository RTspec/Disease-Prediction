# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, recall_score, f1_score

# %%
path = '/content/drive/MyDrive/The_Cancer_data_1500_V2.csv'
df = pd.read_csv(path)

df
# Out:
#       Age  Gender        BMI  Smoking  GeneticRisk  PhysicalActivity  \
# 0      58       1  16.085313        0            1          8.146251
# 1      71       0  30.828784        0            1          9.361630
# 2      48       1  38.785084        0            2          5.135179
# 3      34       0  30.040296        0            0          9.502792
# 4      62       1  35.479721        0            0          5.356890
# ...   ...     ...        ...      ...          ...               ...
# 1495   62       1  25.090025        0            0          9.892167
# 1496   31       0  33.447125        0            1          1.668297
# 1497   63       1  32.613861        1            1          0.466848
# 1498   55       0  25.568216        0            0          7.795317
# 1499   67       1  23.663104        0            0          2.525860
#
#       AlcoholIntake  CancerHistory  Diagnosis
# 0          4.148219              1          1
# 1          3.519683              0          0
# 2          4.728368              0          1
# 3          2.044636              0          0
# 4          3.309849              0          1
# ...             ...            ...        ...
# 1495       1.284158              0          1
# 1496       2.280636              1          1
# 1497       0.150101              0          1
# 1498       1.986138              1          1
# 1499       2.856600              1          0
#
# [1500 rows x 9 columns]

# %%
# Automatically encode text columns to numbers
le = LabelEncoder()
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = le.fit_transform(df[col].astype(str))

#SELECT TARGET & FEATURES
# Replace 'target' with the actual name of your label column
target_col = 'Diagnosis'
X = df.drop(target_col, axis=1)
y = df[target_col]

# Scale features (Critical for SVM and KNN)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# SPLIT DATA
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# INITIALIZE MODELS
algos = {
    "Logistic Regression": LogisticRegression(),
    "SVM": SVC(probability=True),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(n_estimators=100)
}

# TRAIN AND COMPARE
model_performance = []

for name, model in algos.items():
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)

    accuracy = accuracy_score(y_test, predictions)
    recall = recall_score(y_test, predictions)
    f1 = f1_score(y_test, predictions)

    model_performance.append({
        "Algorithm": name,
        "Accuracy": accuracy,
        "Recall (Sensitivity)": recall,
        "F1-Score": f1
    })

# DISPLAY RESULTS
perf_df = pd.DataFrame(model_performance).sort_values(by="Accuracy", ascending=False)
print("\n--- FINAL PERFORMANCE TABLE ---")
print(perf_df)
# Out:
# --- FINAL PERFORMANCE TABLE ---
#              Algorithm  Accuracy  Recall (Sensitivity)  F1-Score
# 4        Random Forest  0.930000              0.879310  0.906667
# 2  K-Nearest Neighbors  0.896667              0.827586  0.860987
# 1                  SVM  0.886667              0.784483  0.842593
# 3        Decision Tree  0.876667              0.810345  0.835556
# 0  Logistic Regression  0.863333              0.758621  0.811060
